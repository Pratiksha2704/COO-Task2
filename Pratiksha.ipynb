# %% [markdown]
# <a href="https://colab.research.google.com/github/Pratiksha2704/COO-Task2/blob/main/Pratiksha.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os

print("Current working directory:", os.getcwd())
# Out:
# Current working directory: /content

# %%
from google.colab import files
import pandas as pd

# Upload file
uploaded = files.upload()

# Load the CSV (replace with your filename after upload)
df = pd.read_csv("Pincode_Dataset.csv")
print(df.head())
# Out:
#      <input type="file" id="files-c1e66bd6-be27-4775-89fa-9a77f007710c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c1e66bd6-be27-4775-89fa-9a77f007710c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# See the shape (rows, columns)
print(df.shape)

# See column names
print(df.columns)

# Summary info
df.info()
# Out:
# (122014, 10)
# Index(['Unnamed: 0', 'Circle Name', 'Region Name', 'Division Name',
#        'Office Name', 'Pincode', 'OfficeType', 'Delivery', 'District',
#        'StateName'],
#       dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 122014 entries, 0 to 122013
# Data columns (total 10 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Unnamed: 0     122014 non-null  int64
#  1   Circle Name    122014 non-null  object
#  2   Region Name    122014 non-null  object
#  3   Division Name  122014 non-null  object
#  4   Office Name    122014 non-null  object
#  5   Pincode        122014 non-null  int64
#  6   OfficeType     122014 non-null  object
#  7   Delivery       122014 non-null  object
#  8   District       122014 non-null  object
#  9   StateName      122014 non-null  object
# dtypes: int64(2), object(8)
# memory usage: 9.3+ MB

# %%
df = df.drop(columns=["Unnamed: 0"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-2209562191.py in <cell line: 0>()
# ----> 1 df = df.drop(columns=["Unnamed: 0"])
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5579                 weight  1.0     0.8
#    5580         """
# -> 5581         return super().drop(
#    5582             labels=labels,
#    5583             axis=axis,
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786         for axis, labels in axes.items():
#    4787             if labels is not None:
# -> 4788                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4789
#    4790         if inplace:
#
# ...

# %%
print(df.columns)
# Out:
# Index(['Circle Name', 'Region Name', 'Division Name', 'Office Name', 'Pincode',
#        'OfficeType', 'Delivery', 'District', 'StateName'],
#       dtype='object')

# %%
# Drop 'Unnamed: 0' only if it exists
if "Unnamed: 0" in df.columns:
    df = df.drop(columns=["Unnamed: 0"])

# %%
# Check for missing values
print(df.isnull().sum())

# Remove duplicate rows (if any)
df = df.drop_duplicates()

# Preview clean dataset
print(df.head())
# Out:
# Circle Name      0
# Region Name      0
# Division Name    0
# Office Name      0
# Pincode          0
# OfficeType       0
# Delivery         0
# District         0
# StateName        0
# dtype: int64
#              Circle Name     Region Name       Division Name  \
# 0  Andhra Pradesh Circle  Kurnool Region  Anantapur Division
# 1  Andhra Pradesh Circle  Kurnool Region  Anantapur Division
# 2  Andhra Pradesh Circle  Kurnool Region  Anantapur Division
# 3  Andhra Pradesh Circle  Kurnool Region  Anantapur Division
# 4  Andhra Pradesh Circle  Kurnool Region  Anantapur Division
#
#            Office Name  Pincode OfficeType  Delivery    District  \
# 0  A Narayanapuram B.O   515004         BO  Delivery  ANANTHAPUR
# 1          Akuledu B.O   515731         BO  Delivery  ANANTHAPUR
# 2          Alamuru B.O   515002         BO  Delivery  ANANTHAPUR
# 3        Allapuram B.O   515766         BO  Delivery  ANANTHAPUR
# 4            Aluru B.O   515415         BO  Delivery  ANANTHAPUR
#
# ...

# %%
df['StateName'].nunique()
# Out:
# 34

# %%
df[df['Pincode'] == 452001]
# Out:
#                  Circle Name    Region Name         Division Name  \
# 42897  Madhya Pradesh Circle  Indore Region  Indore City Division
# 42903  Madhya Pradesh Circle  Indore Region  Indore City Division
# 42907  Madhya Pradesh Circle  Indore Region  Indore City Division
# 42914  Madhya Pradesh Circle  Indore Region  Indore City Division
# 42916  Madhya Pradesh Circle  Indore Region  Indore City Division
# 42917  Madhya Pradesh Circle  Indore Region  Indore City Division
# 42925  Madhya Pradesh Circle  Indore Region  Indore City Division
#
#                      Office Name  Pincode OfficeType      Delivery District  \
# 42897     Indore CGO Complex S.O   452001         SO  Non Delivery   INDORE
# 42903              Indore G.P.O.   452001         HO      Delivery   INDORE
# 42907   Indore Manorama Ganj S.O   452001         SO  Non Delivery   INDORE
# 42914     Indore Takshashila S.O   452001         SO  Non Delivery   INDORE
# ...

# %%
df[df["District"] == "ANANTHAPUR"]
# Out:
#                 Circle Name           Region Name        Division Name  \
# 0     Andhra Pradesh Circle        Kurnool Region   Anantapur Division
# 1     Andhra Pradesh Circle        Kurnool Region   Anantapur Division
# 2     Andhra Pradesh Circle        Kurnool Region   Anantapur Division
# 3     Andhra Pradesh Circle        Kurnool Region   Anantapur Division
# 4     Andhra Pradesh Circle        Kurnool Region   Anantapur Division
# ...                     ...                   ...                  ...
# 469   Andhra Pradesh Circle        Kurnool Region   Anantapur Division
# 470   Andhra Pradesh Circle        Kurnool Region   Anantapur Division
# 1506  Andhra Pradesh Circle        Kurnool Region    Hindupur Division
# 1728  Andhra Pradesh Circle        Kurnool Region    Hindupur Division
# 9982  Andhra Pradesh Circle  Visakhapatnam Region  Srikakulam Division
#
#               Office Name  Pincode OfficeType  Delivery    District  \
# ...

# %%
df["StateName"].value_counts()
# Out:
# StateName
# Uttar Pradesh           17666
# Maharashtra             12752
# Tamil Nadu              11838
# Andhra Pradesh          10494
# Karnataka                9587
# Gujarat                  8858
# West Bengal              8772
# Rajasthan                7959
# Bihar                    6734
# Telangana                5819
# Odisha                   4678
# Madhya Pradesh           4315
# Kerala                   3930
# Punjab                   2668
# Assam                    1768
# Tripura                   727
# Manipur                   708
# Chattisgarh               616
# Megalaya                  469
# Mizoram                   417
# Nagaland                  329
# Arunachal Pradesh         302
# Goa                       259
# Jammu and Kashmir         113
# Andaman and Nico.In.      108
# Dadra and Nagar Hav.       51
# Pondicherry                40
# Daman and Diu              20
# Lakshadweep                11
# Sikkim                      2
# ...

# %%
df["Delivery"].value_counts()
# Out:
# Delivery
# Delivery        115913
# Non Delivery      6101
# Name: count, dtype: int64

# %%
df.to_csv("clean_pincode_data.csv", index=False)

# %%
from google.colab import files

files.download("pincode_data_cleaned.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-2752995447.py in <cell line: 0>()
#       1 from google.colab import files
#       2
# ----> 3 files.download("pincode_data_cleaned.csv")
#
# /usr/local/lib/python3.12/dist-packages/google/colab/files.py in download(filename)
#     231   if not _os.path.exists(filename):
#     232     msg = 'Cannot find file: {}'.format(filename)
# --> 233     raise FileNotFoundError(msg)  # pylint: disable=undefined-variable
#     234
#     235   comm_manager = _IPython.get_ipython().kernel.comm_manager
#
# FileNotFoundError: Cannot find file: pincode_data_cleaned.csv

# %%
import pandas as pd

# Example: assume df is your cleaned DataFrame
df.to_csv("pincode_data_cleaned.csv", index=False)

# %%
from google.colab import files
files.download("pincode_data_cleaned.csv")
